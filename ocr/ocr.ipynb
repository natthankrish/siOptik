# %%
# Import from Python File

from img_process import *
import os

# %%
images_path = get_list_image()

print(images_path)

img = images_path[0]
display_image(img, read_image(img), 1/10)
# Out:
# ['d:\\Folder Kuliah Cadangan\\Sems 6\\PPL\\ocr-android\\data\\C-Hasil-P-PPWP-03-LN-POS-[0].jpg', 'd:\\Folder Kuliah Cadangan\\Sems 6\\PPL\\ocr-android\\data\\C-Hasil-P-PPWP-03-LN-POS-[1].jpg', 'd:\\Folder Kuliah Cadangan\\Sems 6\\PPL\\ocr-android\\data\\C-Hasil-P-PPWP-03-LN-POS-[2].jpg', 'd:\\Folder Kuliah Cadangan\\Sems 6\\PPL\\ocr-android\\data\\C-Hasil-P-PPWP-03-LN-[0].jpg', 'd:\\Folder Kuliah Cadangan\\Sems 6\\PPL\\ocr-android\\data\\C-Hasil-P-PPWP-03-LN-[1].jpg', 'd:\\Folder Kuliah Cadangan\\Sems 6\\PPL\\ocr-android\\data\\C-Hasil-P-PPWP-03-LN-[2].jpg', 'd:\\Folder Kuliah Cadangan\\Sems 6\\PPL\\ocr-android\\data\\C-Hasil-P-PPWP-03-[0].jpg', 'd:\\Folder Kuliah Cadangan\\Sems 6\\PPL\\ocr-android\\data\\C-Hasil-P-PPWP-03-[1].jpg', 'd:\\Folder Kuliah Cadangan\\Sems 6\\PPL\\ocr-android\\data\\C-Hasil-P-PPWP-03-[2].jpg', 'd:\\Folder Kuliah Cadangan\\Sems 6\\PPL\\ocr-android\\data\\CHP-100818X - [DAERAH PEMILIHAN - 08] - LN - H-[0].jpg', 'd:\\Folder Kuliah Cadangan\\Sems 6\\PPL\\ocr-an
# ...
